# %% [markdown]
# # Example 1. Authorizing an application to access Twitter account data

# %%
! pip install twitter
# Out:
# Requirement already satisfied: twitter in /usr/local/lib/python3.7/dist-packages (1.19.3)

# %%
import twitter

# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

# CONSUMER_KEY = '????'
# CONSUMER_SECRET ='????'
# OAUTH_TOKEN = '????'
# OAUTH_TOKEN_SECRET = '????'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7f883db3ed10>

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(world_trends)
# Out:
# [{'trends': [{'name': 'harry styles', 'url': 'http://twitter.com/search?q=%22harry+styles%22', 'promoted_content': None, 'query': '%22harry+styles%22', 'tweet_volume': 130770}, {'name': 'Curitiba', 'url': 'http://twitter.com/search?q=Curitiba', 'promoted_content': None, 'query': 'Curitiba', 'tweet_volume': 19166}, {'name': '#HAPPYJUNKIDAY', 'url': 'http://twitter.com/search?q=%23HAPPYJUNKIDAY', 'promoted_content': None, 'query': '%23HAPPYJUNKIDAY', 'tweet_volume': 131248}, {'name': '#河野純喜の歌声は宝物', 'url': 'http://twitter.com/search?q=%23%E6%B2%B3%E9%87%8E%E7%B4%94%E5%96%9C%E3%81%AE%E6%AD%8C%E5%A3%B0%E3%81%AF%E5%AE%9D%E7%89%A9', 'promoted_content': None, 'query': '%23%E6%B2%B3%E9%87%8E%E7%B4%94%E5%96%9C%E3%81%AE%E6%AD%8C%E5%A3%B0%E3%81%AF%E5%AE%9D%E7%89%A9', 'tweet_volume': 110654}, {'name': 'Gaspard Ulliel', 'url': 'http://twitter.com/search?q=%22Gaspard+Ulliel%22', 'promoted_content': None, 'query': '%22Gaspard+Ulliel%22', 'tweet_volume': 38162}, {'name': '#BamBamSpaces', 'url': 'http://twitter.com/search?q=%23BamBamSpaces', 'promoted_content': None, 'query': '%23BamBamSpaces', 'tweet_volume': 225971}, {'name': 'Bárbara', 'url': 'http://twitter.com/search?q=B%C3%A1rbara', 'promoted_content': None, 'query': 'B%C3%A1rbara', 'tweet_volume': 191429}, {'name': '#PMQs', 'url': 'http://twitter.com/search?q=%23PMQs', 'promoted_content': None, 'query': '%23PMQs', 'tweet_volume': 104000}, {'name': '#乃木坂46ANN', 'url': 'http://twitter.com/search?q=%23%E4%B9%83%E6%9C%A8%E5%9D%8246ANN', 'promoted_content': None, 'query': '%23%E4%B9%83%E6%9C%A8%E5%9D%8246ANN', 'tweet_volume': None}, {'name': 'CONCEPT POSTER MAKNAE LINE', 'url': 'http://twitter.com/search?q=%22CONCEPT+POSTER+MAKNAE+LINE%22', 'promoted_content': None, 'query': '%22CONCEPT+POSTER+MAKNAE+LINE%22', 'tweet_volume': 220756}, {'name': 'Labour', 'url': 'http://twitter.com/search?q=Labour', 'promoted_content': None, 'query': 'Labour', 'tweet_volume': 153322}, {'name': 'The Rings of Power', 'url': 'http://twitter.com/search?q=%22The+Rings+of+Power%22', 'promoted_content': None, 'query': '%22The+Rings+of+Power%22', 'tweet_volume': 17172}, {'name': 'マスターデュエル', 'url': 'http://twitter.com/search?q=%E3%83%9E%E3%82%B9%E3%82%BF%E3%83%BC%E3%83%87%E3%83%A5%E3%82%A8%E3%83%AB', 'promoted_content': None, 'query': '%E3%83%9E%E3%82%B9%E3%82%BF%E3%83%BC%E3%83%87%E3%83%A5%E3%82%A8%E3%83%AB', 'tweet_volume': 99013}, {'name': 'David Davis', 'url': 'http://twitter.com/search?q=%22David+Davis%22', 'promoted_content': None, 'query': '%22David+Davis%22', 'tweet_volume': 28337}, {'name': '純喜くん', 'url': 'http://twitter.com/search?q=%E7%B4%94%E5%96%9C%E3%81%8F%E3%82%93', 'promoted_content': None, 'query': '%E7%B4%94%E5%96%9C%E3%81%8F%E3%82%93', 'tweet_volume': 50532}, {'name': 'BAZINGA KEEP THE BUZZ', 'url': 'http://twitter.com/search?q=%22BAZINGA+KEEP+THE+BUZZ%22', 'promoted_content': None, 'query': '%22BAZINGA+KEEP+THE+BUZZ%22', 'tweet_volume': 362375}, {'name': 'Wordle 215', 'url': 'http://twitter.com/search?q=%22Wordle+215%22', 'promoted_content': None, 'query': '%22Wordle+215%22', 'tweet_volume': None}, {'name': 'Typhlosion', 'url': 'http://twitter.com/search?q=Typhlosion', 'promoted_content': None, 'query': 'Typhlosion', 'tweet_volume': None}, {'name': 'Carola', 'url': 'http://twitter.com/search?q=Carola', 'promoted_content': None, 'query': 'Carola', 'tweet_volume': None}, {'name': '調査隊のテーマ', 'url': 'http://twitter.com/search?q=%E8%AA%BF%E6%9F%BB%E9%9A%8A%E3%81%AE%E3%83%86%E3%83%BC%E3%83%9E', 'promoted_content': None, 'query': '%E8%AA%BF%E6%9F%BB%E9%9A%8A%E3%81%AE%E3%83%86%E3%83%BC%E3%83%9E', 'tweet_volume': 21528}, {'name': 'NEWTON', 'url': 'http://twitter.com/search?q=NEWTON', 'promoted_content': None, 'query': 'NEWTON', 'tweet_volume': None}, {'name': 'ARMY POWERVOTE ON GAON', 'url': 'http://twitter.com/search?q=%22ARMY+POWERVOTE+ON+GAON%22', 'promoted_content': None, 'query': '%22ARMY+POWERVOTE+ON+GAON%22', 'tweet_volume': 133277}, {'name': 'The Lord of the Rings', 'url': 'http://twitter.com/search?q= ...

# %%
print(us_trends)
# Out:
# [{'trends': [{'name': '#VotingRightsForThePeople', 'url': 'http://twitter.com/search?q=%23VotingRightsForThePeople', 'promoted_content': None, 'query': '%23VotingRightsForThePeople', 'tweet_volume': 19442}, {'name': '#WednesdayMotivation', 'url': 'http://twitter.com/search?q=%23WednesdayMotivation', 'promoted_content': None, 'query': '%23WednesdayMotivation', 'tweet_volume': 47581}, {'name': '#DollyParton', 'url': 'http://twitter.com/search?q=%23DollyParton', 'promoted_content': None, 'query': '%23DollyParton', 'tweet_volume': None}, {'name': '#NationalPopcornDay', 'url': 'http://twitter.com/search?q=%23NationalPopcornDay', 'promoted_content': None, 'query': '%23NationalPopcornDay', 'tweet_volume': None}, {'name': 'The Rings of Power', 'url': 'http://twitter.com/search?q=%22The+Rings+of+Power%22', 'promoted_content': None, 'query': '%22The+Rings+of+Power%22', 'tweet_volume': 17172}, {'name': 'Gaspard Ulliel', 'url': 'http://twitter.com/search?q=%22Gaspard+Ulliel%22', 'promoted_content': None, 'query': '%22Gaspard+Ulliel%22', 'tweet_volume': 38383}, {'name': 'Mac Miller', 'url': 'http://twitter.com/search?q=%22Mac+Miller%22', 'promoted_content': None, 'query': '%22Mac+Miller%22', 'tweet_volume': 73958}, {'name': '#TrumpCrimeFamily', 'url': 'http://twitter.com/search?q=%23TrumpCrimeFamily', 'promoted_content': None, 'query': '%23TrumpCrimeFamily', 'tweet_volume': None}, {'name': 'Typhlosion', 'url': 'http://twitter.com/search?q=Typhlosion', 'promoted_content': None, 'query': 'Typhlosion', 'tweet_volume': None}, {'name': 'Wembley', 'url': 'http://twitter.com/search?q=Wembley', 'promoted_content': None, 'query': 'Wembley', 'tweet_volume': None}, {'name': 'CALLAHAN', 'url': 'http://twitter.com/search?q=CALLAHAN', 'promoted_content': None, 'query': 'CALLAHAN', 'tweet_volume': None}, {'name': 'Jennie', 'url': 'http://twitter.com/search?q=Jennie', 'promoted_content': None, 'query': 'Jennie', 'tweet_volume': 77346}, {'name': 'Don Lemon', 'url': 'http://twitter.com/search?q=%22Don+Lemon%22', 'promoted_content': None, 'query': '%22Don+Lemon%22', 'tweet_volume': None}, {'name': 'Hope Hicks', 'url': 'http://twitter.com/search?q=%22Hope+Hicks%22', 'promoted_content': None, 'query': '%22Hope+Hicks%22', 'tweet_volume': None}, {'name': 'ARLO PARKS', 'url': 'http://twitter.com/search?q=%22ARLO+PARKS%22', 'promoted_content': None, 'query': '%22ARLO+PARKS%22', 'tweet_volume': None}, {'name': 'André Leon Talley', 'url': 'http://twitter.com/search?q=%22Andr%C3%A9+Leon+Talley%22', 'promoted_content': None, 'query': '%22Andr%C3%A9+Leon+Talley%22', 'tweet_volume': 95592}, {'name': 'Astroworld', 'url': 'http://twitter.com/search?q=Astroworld', 'promoted_content': None, 'query': 'Astroworld', 'tweet_volume': None}, {'name': 'NY AG', 'url': 'http://twitter.com/search?q=%22NY+AG%22', 'promoted_content': None, 'query': '%22NY+AG%22', 'tweet_volume': None}, {'name': 'Hannibal Rising', 'url': 'http://twitter.com/search?q=%22Hannibal+Rising%22', 'promoted_content': None, 'query': '%22Hannibal+Rising%22', 'tweet_volume': None}, {'name': 'Eric Trump', 'url': 'http://twitter.com/search?q=%22Eric+Trump%22', 'promoted_content': None, 'query': '%22Eric+Trump%22', 'tweet_volume': 53225}, {'name': 'Samurott', 'url': 'http://twitter.com/search?q=Samurott', 'promoted_content': None, 'query': 'Samurott', 'tweet_volume': None}, {'name': 'Decidueye', 'url': 'http://twitter.com/search?q=Decidueye', 'promoted_content': None, 'query': 'Decidueye', 'tweet_volume': None}, {'name': 'Fifth Amendment', 'url': 'http://twitter.com/search?q=%22Fifth+Amendment%22', 'promoted_content': None, 'query': '%22Fifth+Amendment%22', 'tweet_volume': None}, {'name': 'The Lord of the Rings', 'url': 'http://twitter.com/search?q=%22The+Lord+of+the+Rings%22', 'promoted_content': None, 'query': '%22The+Lord+of+the+Rings%22', 'tweet_volume': 19983}, {'name': 'Ukraine', 'url': 'http://twitter.com/search?q=Ukraine', 'promoted_content': None, 'query': 'Ukraine', 'tweet_volume': 169306}, {'name': 'avatar ...

# %% [markdown]
# # Saving data!
#
# Very important!
#
# ![important](https://media.istockphoto.com/photos/important-picture-id186613912?k=6&m=186613912&s=612x612&w=0&h=bMibIfwwjrEW93VWjr3f-wCJwrNn5nyX4TqfitGxwAk=)

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! ls gdrive/MyDrive/ds3010_2022
# Out:
# foo.txt

# %%
# Temporary for this session
import json
data= json.dumps(us_trends, indent=1)

file = open('foo.txt','w')
file.write(data)
file.close()

# %%
# Saved for later sessions!
data= json.dumps(us_trends, indent=1)

file = open('gdrive/MyDrive/ds3010_2022/foo.txt','w')
file.write(data)
file.close()

# %%
file = open('gdrive/MyDrive/ds3010_2022/foo.txt','r')
foo = file.read()
d = json.loads(foo)

print(len(d))
print(d[0].keys())
print(len(d[0]['trends']))
print(d[0]['trends'][27])
# Out:
# 1
# dict_keys(['trends', 'as_of', 'created_at', 'locations'])
# 50
# {'name': 'Hump Day', 'url': 'http://twitter.com/search?q=%22Hump+Day%22', 'promoted_content': None, 'query': '%22Hump+Day%22', 'tweet_volume': 17400}

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

#print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#VotingRightsForThePeople",
#     "url": "http://twitter.com/search?q=%23VotingRightsForThePeople",
#     "promoted_content": null,
#     "query": "%23VotingRightsForThePeople",
#     "tweet_volume": 19442
#    },
#    {
#     "name": "#WednesdayMotivation",
#     "url": "http://twitter.com/search?q=%23WednesdayMotivation",
#     "promoted_content": null,
#     "query": "%23WednesdayMotivation",
#     "tweet_volume": 47581
#    },
#    {
#     "name": "#DollyParton",
#     "url": "http://twitter.com/search?q=%23DollyParton",
#     "promoted_content": null,
#     "query": "%23DollyParton",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NationalPopcornDay",
#     "url": "http://twitter.com/search?q=%23NationalPopcornDay",
#     "promoted_content": null,
#     "query": "%23NationalPopcornDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Rings of Power",
#     "url": "http://twitter.com/search?q=%22The+Rings+of+Power%22",
#     "promoted_content": null,
#     "query": "%22The+Rings+of+Power%22",
#     "tweet_volume": 17172
#    },
#    {
#     "name": "Gaspard Ulliel",
#     "url": "http://twitter.com/search?q=%22Gaspard+Ulliel%22",
#     "promoted_content": null,
#     "query": "%22Gaspard+Ulliel%22",
#     "tweet_volume": 38383
#    },
#    {
#     "name": "Mac Miller",
#     "url": "http://twitter.com/search?q=%22Mac+Miller%22",
#     "promoted_content": null,
#     "query": "%22Mac+Miller%22",
#     "tweet_volume": 73958
#    },
#    {
#     "name": "#TrumpCrimeFamily",
#     "url": "http://twitter.com/search?q=%23TrumpCrimeFamily",
#     "promoted_content": null,
#     "query": "%23TrumpCrimeFamily",
#     "tweet_volume": null
#    },
#    {
#     "name": "Typhlosion",
#     "url": "http://twitter.com/search?q=Typhlosion",
#     "promoted_content": null,
#     "query": "Typhlosion",
#     "tweet_volume": null
#    },
#    {
#     "name": "Wembley",
#     "url": "http://twitter.com/search?q=Wembley",
#     "promoted_content": null,
#     "query": "Wembley",
#     "tweet_volume": null
#    },
#    {
#     "name": "CALLAHAN",
#     "url": "http://twitter.com/search?q=CALLAHAN",
#     "promoted_content": null,
#     "query": "CALLAHAN",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jennie",
#     "url": "http://twitter.com/search?q=Jennie",
#     "promoted_content": null,
#     "query": "Jennie",
#     "tweet_volume": 77346
#    },
#    {
#     "name": "Don Lemon",
#     "url": "http://twitter.com/search?q=%22Don+Lemon%22",
#     "promoted_content": null,
#     "query": "%22Don+Lemon%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hope Hicks",
#     "url": "http://twitter.com/search?q=%22Hope+Hicks%22",
#     "promoted_content": null,
#     "query": "%22Hope+Hicks%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "ARLO PARKS",
#     "url": "http://twitter.com/search?q=%22ARLO+PARKS%22",
#     "promoted_content": null,
#     "query": "%22ARLO+PARKS%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Andr\u00e9 Leon Talley",
#     "url": "http://twitter.com/search?q=%22Andr%C3%A9+Leon+Talley%22",
#     "promoted_content": null,
#     "query": "%22Andr%C3%A9+Leon+Talley%22",
#     "tweet_volume": 95592
#    },
#    {
#     "name": "Astroworld",
#     "url": "http://twitter.com/search?q=Astroworld",
#     "promoted_content": null,
#     "query": "Astroworld",
#     "tweet_volume": null
#    },
#    {
#     "name": "NY AG",
#     "url": "http://twitter.com/search?q=%22NY+AG%22",
#     "promoted_content": null,
#     "query": "%22NY+AG%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hannibal Rising",
#     "url": "http://twitter.com/search?q=%22Hannibal+Rising%22",
#     "promoted_content": null,
#     "query": "%22Hannibal+Rising%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Eric Trump",
#     "url": "http://twitter.com/search?q=%22Eric+Trump%22",
#     "promoted_content": null,
#     "query": "%22Eric+Trump%22",
#     "tweet_volume": 53225
#    },
#    {
#     "name": "Samurott",
#     "url": "http://twitter.com/search?q=Samurott",
#     "promoted_content": null,
#     "query": "Samurott",
#     "tweet_volume": null
#    },
#    {
#     "name": "Decidueye",
#     "url": "http://twitter.com/search?q=Decidueye",
#     "promoted_content": null,
#     "query": "Decidueye",
#     "tweet_volume": null
#    },
#    {
#     "name": "Fifth Amendment",
#     "url": "http://twitter.com/search?q=%22Fifth+Amendment%22",
#     "promoted_content": null,
#     "query": "%22Fifth+Amendment%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Lord of the Rings",
#     "url": "http://twitter.com/search?q=%22The+Lord+of+the+Rings%22",
#     "promoted_content": null,
#     "query": "%22The+Lord+of+the+Rings%22",
#     "tweet_volume": 19983
#    },
#    {
#     "name": "Ukraine",
#     "url": "http://twitter.com/search?q=Ukraine",
#     "promoted_content": null,
#     "query": "Ukraine",
#     "tweet_volume": 169306
#    },
#    {
#     "name": "avatar 2",
#     "url": "http://twitter.com/search?q=%22avatar+2%22",
#     "promoted_content": null,
#     "query": "%22avatar+2%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Edgar Allan Poe",
#     "url": "http://twitter.com/search?q=%22Edgar+Allan+Poe%22",
#     "promoted_content": null,
#     "query": "%22Edgar+Allan+Poe%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hump Day",
#     "url": "http://twitter.com/search?q=%22Hump+Day%22",
#     "promoted_content": null,
#     "query": "%22Hump+Day%22",
#     "tweet_volume": 17400
#    },
#    {
#     "name": "Legends Arceus",
#     "url": "http://twitter.com/search?q=%22Legends+Arceus%22",
#     "promoted_content": null,
#     "query": "%22Legends+Arceus%22",
#     "tweet_volume": 10374
#    },
#    {
#     "name": "harries",
#     "url": "http://twitter.com/search?q=harries",
#     "promoted_content": null,
#     "query": "harries",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sabonis",
#     "url": "http://twitter.com/search?q=Sabonis",
#     "promoted_content": null,
#     "query": "Sabonis",
#     "tweet_volume": null
#    },
#    {
#     "name": "Palkia",
#     "url": "http://twitter.com/search?q=Palkia",
#     "promoted_content": null,
#     "query": "Palkia",
#     "tweet_volume": null
#    },
#    {
#     "name": "wolf alice",
#     "url": "http://twitter.com/search?q=%22wolf+alice%22",
#     "promoted_content": null,
#     "query": "%22wolf+alice%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Master Duel",
#     "url": "http://twitter.com/search?q=%22Master+Duel%22",
#     "promoted_content": null,
#     "query": "%22Master+Duel%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "HARRY AND MITSKI",
#     "url": "http://twitter.com/search?q=%22HARRY+AND+MITSKI%22",
#     "promoted_content": null,
#     "query": "%22HARRY+AND+MITSKI%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dialga",
#     "url": "http://twitter.com/search?q=Dialga",
#     "promoted_content": null,
#     "query": "Dialga",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Trumps",
#     "url": "http://twitter.com/search?q=%22The+Trumps%22",
#     "promoted_content": null,
#     "query": "%22The+Trumps%22",
#     "tweet_volume": 18490
#    },
#    {
#     "name": "Tall Girl 2",
#     "url": "http://twitter.com/search?q=%22Tall+Girl+2%22",
#     "promoted_content": null,
#     "query": "%22Tall+Girl+2%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Northing",
#     "url": "http://twitter.com/search?q=Northing",
#     "promoted_content": null,
#     "query": "Northing",
#     "tweet_volume": null
#    },
#    {
#     "name": "Vogue",
#     "url": "http://twitter.com/search?q=Vogue",
#     "promoted_content": null,
#     "query": "Vogue",
#     "tweet_volume": 48838
#    },
#    {
#     "name": "Nene",
#     "url": "http://twitter.com/search?q=Nene",
#     "promoted_content": null,
#     "query": "Nene",
#     "tweet_volume": 42123
#    },
#    {
#     "name": "Happy 30th",
#     "url": "http://twitter.com/search?q=%22Happy+30th%22",
#     "promoted_content": null,
#     "query": "%22Happy+30th%22",
#     "tweet_volume": 10448
#    },
#    {
#     "name": "Happy Birthday Pete",
#     "url": "http://twitter.com/search?q=%22Happy+Birthday+Pete%22",
#     "promoted_content": null,
#     "query": "%22Happy+Birthday+Pete%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "New York AG",
#     "url": "http://twitter.com/search?q=%22New+York+AG%22",
#     "promoted_content": null,
#     "query": "%22New+York+AG%22",
#     "tweet_volume": 17302
#    },
#    {
#     "name": "Walter",
#     "url": "http://twitter.com/search?q=Walter",
#     "promoted_content": null,
#     "query": "Walter",
#     "tweet_volume": 38368
#    },
#    {
#     "name": "Anna Wintour",
#     "url": "http://twitter.com/search?q=%22Anna+Wintour%22",
#     "promoted_content": null,
#     "query": "%22Anna+Wintour%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Shangela",
#     "url": "http://twitter.com/search?q=Shangela",
#     "promoted_content": null,
#     "query": "Shangela",
#     "tweet_volume": null
#    },
#    {
#     "name": "Letitia James",
#     "url": "http://twitter.com/search?q=%22Letitia+James%22",
#     "promoted_content": null,
#     "query": "%22Letitia+James%22",
#     "tweet_volume": 37602
#    },
#    {
#     "name": "Trump Org",
#     "url": "http://twitter.com/search?q=%22Trump+Org%22",
#     "promoted_content": null,
#     "query": "%22Trump+Org%22",
#     "tweet_volume": 17342
#    },
#    {
#     "name": "Mel Gibson",
#     "url": "http://twitter.com/search?q=%22Mel+Gibson%22",
#     "promoted_content": null,
#     "query": "%22Mel+Gibson%22",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2022-01-19T16:04:01Z",
#   "created_at": "2022-01-17T06:36:05Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %%
len(us_trends[0]['trends'])
for i in range(50):
    print(us_trends[0]['trends'][i]['url'])
    print(us_trends[0]['trends'][i]['query'])
# Out:
# http://twitter.com/search?q=%23VotingRightsForThePeople
# %23VotingRightsForThePeople
# http://twitter.com/search?q=%23WednesdayMotivation
# %23WednesdayMotivation
# http://twitter.com/search?q=%23DollyParton
# %23DollyParton
# http://twitter.com/search?q=%23NationalPopcornDay
# %23NationalPopcornDay
# http://twitter.com/search?q=%22The+Rings+of+Power%22
# %22The+Rings+of+Power%22
# http://twitter.com/search?q=%22Gaspard+Ulliel%22
# %22Gaspard+Ulliel%22
# http://twitter.com/search?q=%22Mac+Miller%22
# %22Mac+Miller%22
# http://twitter.com/search?q=%23TrumpCrimeFamily
# %23TrumpCrimeFamily
# http://twitter.com/search?q=Typhlosion
# Typhlosion
# http://twitter.com/search?q=Wembley
# Wembley
# http://twitter.com/search?q=CALLAHAN
# CALLAHAN
# http://twitter.com/search?q=Jennie
# Jennie
# http://twitter.com/search?q=%22Don+Lemon%22
# %22Don+Lemon%22
# http://twitter.com/search?q=%22Hope+Hicks%22
# %22Hope+Hicks%22
# http://twitter.com/search?q=%22ARLO+PARKS%22
# %22ARLO+PARKS%22
# http://twitter.com/search?q=%22Andr%C3%A9+Leon+Talley%22
# %22Andr%C3%A9+Leon+Talley%22
# http://twitter.com/search?q=Astroworld
# Astroworld
# http://twitter.com/search?q=%22NY+AG%22
# %22NY+AG%22
# http://twitter.com/search?q=%22Hannibal+Rising%22
# %22Hannibal+Rising%22
# http://twitter.com/search?q=%22Eric+Trump%22
# %22Eric+Trump%22
# http://twitter.com/search?q=Samurott
# Samurott
# http://twitter.com/search?q=Decidueye
# Decidueye
# http://twitter.com/search?q=%22Fifth+Amendment%22
# %22Fifth+Amendment%22
# http://twitter.com/search?q=%22The+Lord+of+the+Rings%22
# %22The+Lord+of+the+Rings%22
# http://twitter.com/search?q=Ukraine
# Ukraine
# http://twitter.com/search?q=%22avatar+2%22
# %22avatar+2%22
# http://twitter.com/search?q=%22Edgar+Allan+Poe%22
# %22Edgar+Allan+Poe%22
# http://twitter.com/search?q=%22Hump+Day%22
# %22Hump+Day%22
# http://twitter.com/search?q=%22Legends+Arceus%22
# %22Legends+Arceus%22
# http://twitter.com/search?q=harries
# harries
# http://twitter.com/search?q=Sabonis
# Sabonis
# http://twitter.com/search?q=Palkia
# Palkia
# http://twitter.com/search?q=%22wolf+alice%22
# %22wolf+alice%22
# http://twitter.com/search?q=%22Master+Duel%22
# %22Master+Duel%22
# http://twitter.com/search?q=%22HARRY+AND+MITSKI%22
# %22HARRY+AND+MITSKI%22
# http://twitter.com/search?q=Dialga
# Dialga
# http://twitter.com/search?q=%22The+Trumps%22
# %22The+Trumps%22
# http://twitter.com/search?q=%22Tall+Girl+2%22
# %22Tall+Girl+2%22
# http://twitter.com/search?q=Northing
# Northing
# http://twitter.com/search?q=Vogue
# Vogue
# http://twitter.com/search?q=Nene
# Nene
# http://twitter.com/search?q=%22Happy+30th%22
# %22Happy+30th%22
# http://twitter.com/search?q=%22Happy+Birthday+Pete%22
# %22Happy+Birthday+Pete%22
# http://twitter.com/search?q=%22New+York+AG%22
# %22New+York+AG%22
# http://twitter.com/search?q=Walter
# Walter
# http://twitter.com/search?q=%22Anna+Wintour%22
# %22Anna+Wintour%22
# http://twitter.com/search?q=Shangela
# Shangela
# http://twitter.com/search?q=%22Letitia+James%22
# %22Letitia+James%22
# http://twitter.com/search?q=%22Trump+Org%22
# %22Trump+Org%22
# http://twitter.com/search?q=%22Mel+Gibson%22
# %22Mel+Gibson%22

# %% [markdown]
# # Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'The Lord of the Rings', 'Hannibal Rising', 'Typhlosion', 'Dialga', 'Wembley', 'Decidueye', 'Mac Miller', 'ARLO PARKS', 'Gaspard Ulliel', 'Palkia', 'CALLAHAN', 'Samurott', 'The Rings of Power'}

# %%
world_trends[0]['trends'][0]['name']
# Out:
# 'harry styles'

# %%
world_trends_set
# Out:
# {'#BamBamSpaces',
#  '#HAPPYJUNKIDAY',
#  '#HARUTO',
#  '#KeremBürsinBMW',
#  '#PMQs',
#  '#SAvIND',
#  '#SMOK',
#  '#SOJUNGHWAN',
#  '#elektrik',
#  '#フワちゃんANNX',
#  '#乃木坂46ANN',
#  '#河野純喜の歌声は宝物',
#  'ARLO PARKS',
#  'ARMY POWERVOTE ON GAON',
#  'Arceus',
#  'BAZINGA KEEP THE BUZZ',
#  'BUTTER FOR SEVEN',
#  'Bury South',
#  'Bárbara',
#  'CALLAHAN',
#  'CONCEPT POSTER MAKNAE LINE',
#  'Carola',
#  'Christian Wakeford',
#  'Curitiba',
#  'David Davis',
#  'Decidueye',
#  'Dialga',
#  'Gaspard Ulliel',
#  'Hannibal Rising',
#  'JUNGHWAN NEW ERA',
#  'Labour',
#  'Mac Miller',
#  'NEWTON',
#  'Palkia',
#  'Salitre Mágico',
#  'Samurott',
#  'The Lord of the Rings',
#  'The Rings of Power',
#  'Todaro',
#  'Typhlosion',
#  'WOLF ALICE',
#  'Wembley',
#  'Wordle 215',
#  'harry styles',
#  'ticketmaster',
#  'ダブルパーカー',
#  'マスターデュエル',
#  '春日さん',
#  '純喜くん',
#  '調査隊のテーマ'}

# %%
print(u'#\u0645\u0639\u0644\u0645\u064a\u0646_\u0627\u0644\u0627\u0631\u0628\u0639_\u0639\u0627\u0644\u0631\u0627\u062f\u064a\u0648_9090')
# Out:
# #معلمين_الاربع_عالراديو_9090

# %%
print(u'#\u0628\u0642\u0648\u0644_\u0643\u0641\u0627\u064a\u0647_\u0644')
# Out:
# #بقول_كفايه_ل

# %% [markdown]
# # Example 5. Collecting search results

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json

#q = '#Kayne' 
#q = '#Paffenroth' 
q = '#Toyota'
#q = "andrew"

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#                         "id_str": "1483761102869569537",
#                         "indices": [
#                             32,
#                             55
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                         "url": "https://t.co/aptxCLKCxS",
#                         "display_url": "pic.twitter.com/aptxCLKCxS",
#                         "expanded_url": "https://twitter.com/Retromirai/status/1483761109056114692/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1483761102869569537,
#                         "id_str": "1483761102869569537",
#                         "indices": [
#                             32,
#                             55
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                         "url": "https://t.co/aptxCLKCxS",
#                         "display_url": "pic.twitter.com/aptxCLKCxS",
#                         "expanded_url": "https://twitter.com/Retromirai/status/1483761109056114692/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "und",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1101048800045543425,
#                 "id_str": "1101048800045543425",
#                 "name": "\u308c\u3068\u308d\u307f\u3089\u3044",
#                 "screen_name": "Retromirai",
#                 "location": "",
#                 "description": "\u3086\u308b\u3044\u7d75\u3092\u63cf\u3044\u305f\u308a\u3001\u97f3\u697d\u3092\u4f5c\u3063\u305f\u308a\u3057\u307e\u3059\u3002 \u3086\u3081\u306b\u3063\u304d(\u6d3e\u751f)\u3068\u8eca\u3068\u97f3\u697d(YMO\u3001kraftwerk\u3001\u59eb\u795e\u3001Raujika)\u3068\u30ab\u30ec\u30fc\u304c\u597d\u304d\u3002\u3042\uff01\u3042\u3068\u304a\u7b11\u3044\u3081\u3063\u3061\u3083\u597d\u304d\u3067\u3059\u3002",
#                 "url": "https://t.co/NCJPW1mXZT",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/NCJPW1mXZT",
#                                 "expanded_url": "https://soundcloud.com/retromirai",
#                                 "display_url": "soundcloud.com/retromirai",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 1072,
#                 "friends_count": 762,
#                 "listed_count": 24,
#                 "created_at": "Thu Feb 28 09:17:45 +0000 2019",
#                 "favourites_count": 9289,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 4065,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1251850696741142528/rlNgzmWB_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1251850696741142528/rlNgzmWB_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1101048800045543425/1625179949",
#                 "profile_link_color": "F8E9CC",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 9,
#             "favorite_count": 36,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "und"
#         },
#         "is_quote_status": false,
#         "retweet_count": 9,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "und"
#     },
#     {
#         "created_at": "Wed Jan 19 11:51:37 +0000 2022",
#         "id": 1483769109628260352,
#         "id_str": "1483769109628260352",
#         "text": "#\u583a\u6d5c\u3086\u308b\u3086\u308b\u30b0\u30c0\u30b0\u30c0\u30aa\u30d5\u4f1a #\u583a\u6d5c\u3086\u308b\u30b0\u30c0\u30aa\u30d5\u4f1a #\u583a\u6d5c\u3086\u308b\u30b0\u30c0 \n#\u30c8\u30e8\u30bf #toyota #\u30bb\u30ea\u30ab #celica #gtv #\u30c0\u30eb\u30de\u30bb\u30ea\u30ab #\u30d1\u30d6\u30ea\u30ab #publica #\u30d1\u30d6\u30ea\u30ab800 #publica800 #up20\u2026 https://t.co/UnRYxh1xtd",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "\u583a\u6d5c\u3086\u308b\u3086\u308b\u30b0\u30c0\u30b0\u30c0\u30aa\u30d5\u4f1a",
#                     "indices": [
#                         0,
#                         14
#                     ]
#                 },
#                 {
#                     "text": "\u583a\u6d5c\u3086\u308b\u30b0\u30c0\u30aa\u30d5\u4f1a",
#                     "indices": [
#                         15,
#                         25
#                     ]
#                 },
#                 {
#                     "text": "\u583a\u6d5c\u3086\u308b\u30b0\u30c0",
#                     "indices": [
#                         26,
#                         33
#                     ]
#                 },
#                 {
#                     "text": "\u30c8\u30e8\u30bf",
#                     "indices": [
#                         35,
#                         39
#                     ]
#                 },
#                 {
#                     "text": "toyota",
#                     "indices": [
#                         40,
#                         47
#                     ]
#                 },
#                 {
#                     "text": "\u30bb\u30ea\u30ab",
#                     "indices": [
#                         48,
#                         52
#                     ]
#                 },
#                 {
#                     "text": "celica",
#                     "indices": [
#                         53,
#                         60
#                     ]
#                 },
#                 {
#                     "text": "gtv",
#                     "indices": [
#                         61,
#                         65
#                     ]
#                 },
#                 {
#                     "text": "\u30c0\u30eb\u30de\u30bb\u30ea\u30ab",
#                     "indices": [
#                         66,
#                         73
#                     ]
#                 },
#                 {
#                     "text": "\u30d1\u30d6\u30ea\u30ab",
#                     "indices": [
#                         74,
#                         79
#                     ]
#                 },
#                 {
#                     "text": "publica",
#                     "indices": [
#                         80,
#                         88
#                     ]
#                 },
#                 {
#                     "text": "\u30d1\u30d6\u30ea\u30ab800",
#                     "indices": [
#                         89,
#                         97
#                     ]
#                 },
#                 {
#                     "text": "publica800",
#                     "indices": [
#                         98,
#                         109
#                     ]
#                 },
#                 {
#                     "text": "up20",
#                     "indices": [
#                         110,
#                         115
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/UnRYxh1xtd",
#                     "expanded_url": "https://twitter.com/i/web/status/1483769109628260352",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "ja",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 581573368,
#             "id_str": "581573368",
#             "name": "\u3053\u3070\u3093",
#             "screen_name": "cedric_130",
#             "location": "",
#             "description": "\u4e2d\u5e74\u306e\u30aa\u30c3\u30b5\u30f3\u306e\u622f\u8a00\u3067\u3059\u3002\u6c17\u306b\u3057\u306a\u3044\u3067\u304f\u3060\u3055\u3044\u3002",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 95,
#             "friends_count": 70,
#             "listed_count": 6,
#             "created_at": "Wed May 16 06:13:05 +0000 2012",
#             "favourites_count": 6997,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 3455,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1023466853358755841/5_PM4Pt5_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1023466853358755841/5_PM4Pt5_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/581573368/1532848057",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": {
#             "type": "Point",
#             "coordinates": [
#                 34.601205,
#                 135.42683235
#             ]
#         },
#         "coordinates": {
#             "type": "Point",
#             "coordinates": [
#                 135.42683235,
#                 34.601205
#             ]
#         },
#         "place": {
#             "id": "999694acfaba33dd",
#             "url": "https://api.twitter.com/1.1/geo/id/999694acfaba33dd.json",
#             "place_type": "city",
#             "name": "Sakai City Sakai Ward",
#             "full_name": "Sakai-shi Sakai, Osaka",
#             "country_code": "JP",
#             "country": "Japan",
#             "contained_within": [],
#             "bounding_box": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             135.423966004972,
#                             34.5447929950167
#                         ],
#                         [
#                             135.506078999222,
#                             34.5447929950167
#                         ],
#                         [
#                             135.506078999222,
#                             34.6084920013048
#                         ],
#                         [
#                             135.423966004972,
#                             34.6084920013048
#                         ]
#                     ]
#                 ]
#             },
#             "attributes": {}
#         },
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "ja"
#     },
#     {
#         "created_at": "Wed Jan 19 11:51:34 +0000 2022",
#         "id": 1483769096839868418,
#         "id_str": "1483769096839868418",
#         "text": "RT @Frtluan92: 86 GRMN \n\u2014\u2014\u2014\u2014\u2014\n@Toyota @thegranturismo #Toyota #GTSport #Virtualphotography #VGPUnite #TheCapturedCollective #GSVP #ThePhoto\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Toyota",
#                     "indices": [
#                         54,
#                         61
#                     ]
#                 },
#                 {
#                     "text": "GTSport",
#                     "indices": [
#                         62,
#                         70
#                     ]
#                 },
#                 {
#                     "text": "Virtualphotography",
#                     "indices": [
#                         71,
#                         90
#                     ]
#                 },
#                 {
#                     "text": "VGPUnite",
#                     "indices": [
#                         91,
#                         100
#                     ]
#                 },
#                 {
#                     "text": "TheCapturedCollective",
#                     "indices": [
#                         101,
#                         123
#                     ]
#                 },
#                 {
#                     "text": "GSVP",
#                     "indices": [
#                         124,
#                         129
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "Frtluan92",
#                     "name": "FRT Luan",
#                     "id": 3874929107,
#                     "id_str": "3874929107",
#                     "indices": [
#                         3,
#                         13
#                     ]
#                 },
#                 {
#                     "screen_name": "Toyota",
#                     "name": "Toyota USA",
#                     "id": 14219877,
#                     "id_str": "14219877",
#                     "indices": [
#                         30,
#                         37
#                     ]
#                 },
#                 {
#                     "screen_name": "thegranturismo",
#                     "name": "Gran Turismo",
#                     "id": 2165171719,
#                     "id_str": "2165171719",
#                     "indices": [
#                         38,
#                         53
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "in",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 966386408373006339,
#             "id_str": "966386408373006339",
#             "name": "ConnerSpeed6",
#             "screen_name": "ConnerSpeed6",
#             "location": "Horizon Festival, Mexico \ud83c\uddf2\ud83c\uddfd",
#             "description": "ConnerSpeed6 | Racing Game Youtuber With 6,700+ Subscribers \ud83d\udcc8 | Instagram, Facebook, Xbox: ConnerSpeed6 | (#CS6) CS6 Rally Team | Join The #SpeedSquad!\ud83d\udc47",
#             "url": "https://t.co/mdM3rlhMAE",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/mdM3rlhMAE",
#                             "expanded_url": "https://www.youtube.com/c/ConnerSpeed6",
#                             "display_url": "youtube.com/c/ConnerSpeed6",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 2088,
#             "friends_count": 1118,
#             "listed_count": 12,
#             "created_at": "Wed Feb 21 18:57:29 +0000 2018",
#             "favourites_count": 48799,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 15070,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1455128854683693072/YewTdjRj_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1455128854683693072/YewTdjRj_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/966386408373006339/1627494374",
#             "profile_link_color": "19CF86",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Jan 17 15:12:53 +0000 2022",
#             "id": 1483094983511060480,
#             "id_str": "1483094983511060480",
#             "text": "86 GRMN \n\u2014\u2014\u2014\u2014\u2014\n@Toyota @thegranturismo #Toyota #GTSport #Virtualphotography #VGPUnite #TheCapturedCollective #GSVP\u2026 https://t.co/u4kFHojbZS",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Toyota",
#                         "indices": [
#                             39,
#                             46
#                         ]
#                     },
#                     {
#                         "text": "GTSport",
#                         "indices": [
#                             47,
#                             55
#                         ]
#                     },
#                     {
#                         "text": "Virtualphotography",
#                         "indices": [
#                             56,
#                             75
#                         ]
#                     },
#                     {
#                         "text": "VGPUnite",
#                         "indices": [
#                             76,
#                             85
#                         ]
#                     },
#                     {
#                         "text": "TheCapturedCollective",
#                         "indices": [
#                             86,
#                             108
#                         ]
#                     },
#                     {
#                         "text": "GSVP",
#                         "indices": [
#                             109,
#                             114
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "Toyota",
#                         "name": "Toyota USA",
#                         "id": 14219877,
#                         "id_str": "14219877",
#                         "indices": [
#                             15,
#                             22
#                         ]
#                     },
#                     {
#                         "screen_name": "thegranturismo",
#                         "name": "Gran Turismo",
#                         "id": 2165171719,
#                         "id_str": "2165171719",
#                         "indices": [
#                             23,
#                             38
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/u4kFHojbZS",
#                         "expanded_url": "https://twitter.com/i/web/status/1483094983511060480",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             116,
#                             139
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "in",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 3874929107,
#                 "id_str": "3874929107",
#                 "name": "FRT Luan",
#                 "screen_name": "Frtluan92",
#                 "location": "Rio Grande do Sul, Brasil",
#                 "description": "Virtual Photographer and Photographer of FRT Team | Instagram: https://t.co/bindjrtrE2 | Xbox: FRT Luan | PSN: Frt_luan92",
#                 "url": "https://t.co/c3ZuOpwj4g",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/c3ZuOpwj4g",
#                                 "expanded_url": "https://500px.com/luanenneslmk",
#                                 "display_url": "500px.com/luanenneslmk",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/bindjrtrE2",
#                                 "expanded_url": "https://www.instagram.com/frtluan/",
#                                 "display_url": "instagram.com/frtluan/",
#                                 "indices": [
#                                     63,
#                                     86
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 1019,
#                 "friends_count": 1096,
#                 "listed_count": 12,
#                 "created_at": "Mon Oct 05 22:21:10 +0000 2015",
#                 "favourites_count": 110516,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 9392,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1482386748487389195/sl9-QOVu_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1482386748487389195/sl9-QOVu_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/3874929107/1639323047",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 6,
#             "favorite_count": 78,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "in"
#         },
#         "is_quote_status": false,
#         "retweet_count": 6,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "in"
#     },
#     {
#         "created_at": "Wed Jan 19 11:51:17 +0000 2022",
#         "id": 1483769026530656259,
#         "id_str": "1483769026530656259",
#         "text": "RT @CarPicsNow: #TOYOTA COROLLA (2018) \ud83c\udfce\ud83d\udca8\ud83d\udca8\ud83d\udca8 https://t.co/pUcwW7MwXS",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "TOYOTA",
#                     "indices": [
#                         16,
#                         23
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "CarPicsNow",
#                     "name": "Car Porn",
#                     "id": 1259866426158047233,
#                     "id_str": "1259866426158047233",
#                     "indices": [
#                         3,
#                         14
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1470929991894503428,
#                     "id_str": "1470929991894503428",
#                     "indices": [
#                         44,
#                         67
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FGnLCMhXEAQUlYi.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FGnLCMhXEAQUlYi.jpg",
#                     "url": "https://t.co/pUcwW7MwXS",
#                     "display_url": "pic.twitter.com/pUcwW7MwXS",
#                     "expanded_url": "https://twitter.com/CarPicsNow/status/1470929997137330178/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1470929997137330178,
#                     "source_status_id_str": "1470929997137330178",
#                     "source_user_id": 1259866426158047233,
#                     "source_user_id_str": "1259866426158047233"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1470929991894503428,
#                     "id_str": "1470929991894503428",
#                     "indices": [
#                         44,
#                         67
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FGnLCMhXEAQUlYi.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FGnLCMhXEAQUlYi.jpg",
#                     "url": "https://t.co/pUcwW7MwXS",
#                     "display_url": "pic.twitter.com/pUcwW7MwXS",
#                     "expanded_url": "https://twitter.com/CarPicsNow/status/1470929997137330178/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1470929997137330178,
#                     "source_status_id_str": "1470929997137330178",
#                     "source_user_id": 1259866426158047233,
#                     "source_user_id_str": "1259866426158047233"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "it",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1269172554683555841,
#             "id_str": "1269172554683555841",
#             "name": "painkiller",
#             "screen_name": "PrototypeEvi1",
#             "location": "Asia",
#             "description": "world is game of selected & move",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 50,
#             "friends_count": 699,
#             "listed_count": 1,
#             "created_at": "Sat Jun 06 07:41:42 +0000 2020",
#             "favourites_count": 5384,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 13246,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1480546807482658817/-Ds6XbZH_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1480546807482658817/-Ds6XbZH_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1269172554683555841/1641542913",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Wed Dec 15 01:33:34 +0000 2021",
#             "id": 1470929997137330178,
#             "id_str": "1470929997137330178",
#             "text": "#TOYOTA COROLLA (2018) \ud83c\udfce\ud83d\udca8\ud83d\udca8\ud83d\udca8 https://t.co/pUcwW7MwXS",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "TOYOTA",
#                         "indices": [
#                             0,
#                             7
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1470929991894503428,
#                         "id_str": "1470929991894503428",
#                         "indices": [
#                             28,
#                             51
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FGnLCMhXEAQUlYi.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FGnLCMhXEAQUlYi.jpg",
#                         "url": "https://t.co/pUcwW7MwXS",
#                         "display_url": "pic.twitter.com/pUcwW7MwXS",
#                         "expanded_url": "https://twitter.com/CarPicsNow/status/1470929997137330178/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1470929991894503428,
#                         "id_str": "1470929991894503428",
#                         "indices": [
#                             28,
#                             51
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FGnLCMhXEAQUlYi.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FGnLCMhXEAQUlYi.jpg",
#                         "url": "https://t.co/pUcwW7MwXS",
#                         "display_url": "pic.twitter.com/pUcwW7MwXS",
#                         "expanded_url": "https://twitter.com/CarPicsNow/status/1470929997137330178/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "it",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1259866426158047233,
#                 "id_str": "1259866426158047233",
#                 "name": "Car Porn",
#                 "screen_name": "CarPicsNow",
#                 "location": "",
#                 "description": "Daily car porn : ) We do not own content posted. No copyright infringement intended.",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 3620,
#                 "friends_count": 4373,
#                 "listed_count": 10,
#                 "created_at": "Mon May 11 15:22:27 +0000 2020",
#                 "favourites_count": 69,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 616,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1259869140724199427/6F6xogG2_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1259869140724199427/6F6xogG2_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1259866426158047233/1589211351",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 13,
#             "favorite_count": 109,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "it"
#         },
#         "is_quote_status": false,
#         "retweet_count": 13,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "it"
#     },
#     {
#         "created_at": "Wed Jan 19 11:50:29 +0000 2022",
#         "id": 1483768823639588867,
#         "id_str": "1483768823639588867",
#         "text": "Vitz Gang \ud83d\ude99\ud83d\ude99\ud83d\ude99\n\n\ud83d\ude97\ud83d\ude97This Toyota Vitz KCB. Is ready for viewing upon request \n\n\ud83d\ude99\ud83d\ude99Going for Kes.470k\n\n\ud83d\udccdEmbu.\n\nContact us\u2026 https://t.co/3BujtTnHmv",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/3BujtTnHmv",
#                     "expanded_url": "https://twitter.com/i/web/status/1483768823639588867",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 873100389842788354,
#             "id_str": "873100389842788354",
#             "name": "Penny Auto",
#             "screen_name": "pennyauto_",
#             "location": "Nairobi, Kenya",
#             "description": "Command attention on the road!",
#             "url": "https://t.co/4sjZqk5yFh",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4sjZqk5yFh",
#                             "expanded_url": "http://www.pennydenari.co.ke",
#                             "display_url": "pennydenari.co.ke",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 29,
#             "friends_count": 153,
#             "listed_count": 0,
#             "created_at": "Fri Jun 09 08:52:09 +0000 2017",
#             "favourites_count": 7,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 2,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1478243362205540354/eVhMSqcv_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1478243362205540354/eVhMSqcv_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/873100389842788354/1641275711",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
# ...
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1483761102869569537,
#                     "id_str": "1483761102869569537",
#                     "indices": [
#                         48,
#                         71
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                     "url": "https://t.co/aptxCLKCxS",
#                     "display_url": "pic.twitter.com/aptxCLKCxS",
#                     "expanded_url": "https://twitter.com/Retromirai/status/1483761109056114692/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1483761109056114692,
#                     "source_status_id_str": "1483761109056114692",
#                     "source_user_id": 1101048800045543425,
#                     "source_user_id_str": "1101048800045543425"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1483761102869569537,
#                     "id_str": "1483761102869569537",
#                     "indices": [
#                         48,
#                         71
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                     "url": "https://t.co/aptxCLKCxS",
#                     "display_url": "pic.twitter.com/aptxCLKCxS",
#                     "expanded_url": "https://twitter.com/Retromirai/status/1483761109056114692/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1483761109056114692,
#                     "source_status_id_str": "1483761109056114692",
#                     "source_user_id": 1101048800045543425,
#                     "source_user_id_str": "1101048800045543425"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "und",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 977048376767258624,
#             "id_str": "977048376767258624",
#             "name": "\u304a\u3055\u3064\u3079\u3044.pdf",
#             "screen_name": "Osatu_R",
#             "location": "53520 N\u00fcrnberg",
#             "description": "\u5e38\u8b58\u306e\u6b20\u5982\n@MonHan_3G_Fleed\u306f\u4ffa\u306e\u5144\u8cb4\u5206\n\u30d8\u30c3\u30c0\u30fc\u306f @stop404man\u3055\u3093\u304b\u3089\n\u203bDM\u3084LINE\u7b49\u306e\u5185\u5bb9\u306f\u500b\u4eba\u60c5\u5831\u3092\u96a0\u3057\u305f\u5f62\u3067\u516c\u958b\u3059\u308b\u53ef\u80fd\u6027\u304c\u3042\u308a\u307e\u3059\n\u5984\u60f3\u5782\u308c\u6d41\u3059\u306e\u3067\u3054\u6ce8\u610f\u3092",
#             "url": "https://t.co/ywA7QnAzC1",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/ywA7QnAzC1",
#                             "expanded_url": "https://discord.gg/4DmXBKFv4W",
#                             "display_url": "discord.gg/4DmXBKFv4W",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1179,
#             "friends_count": 1870,
#             "listed_count": 19,
#             "created_at": "Fri Mar 23 05:04:20 +0000 2018",
#             "favourites_count": 76660,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 53685,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1374265010956902401/ECKE9Wjh_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1374265010956902401/ECKE9Wjh_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/977048376767258624/1560981722",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Wed Jan 19 11:19:50 +0000 2022",
#             "id": 1483761109056114692,
#             "id_str": "1483761109056114692",
#             "text": "#toyota #tjcruiser #illustraion https://t.co/aptxCLKCxS",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "toyota",
#                         "indices": [
#                             0,
#                             7
#                         ]
#                     },
#                     {
#                         "text": "tjcruiser",
#                         "indices": [
#                             8,
#                             18
#                         ]
#                     },
#                     {
#                         "text": "illustraion",
#                         "indices": [
#                             19,
#                             31
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1483761102869569537,
#                         "id_str": "1483761102869569537",
#                         "indices": [
#                             32,
#                             55
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                         "url": "https://t.co/aptxCLKCxS",
#                         "display_url": "pic.twitter.com/aptxCLKCxS",
#                         "expanded_url": "https://twitter.com/Retromirai/status/1483761109056114692/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1483761102869569537,
#                         "id_str": "1483761102869569537",
#                         "indices": [
#                             32,
#                             55
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FJdg3JwVIAEG3-Y.jpg",
#                         "url": "https://t.co/aptxCLKCxS",
#                         "display_url": "pic.twitter.com/aptxCLKCxS",
#                         "expanded_url": "https://twitter.com/Retromirai/status/1483761109056114692/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "und",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1101048800045543425,
#                 "id_str": "1101048800045543425",
#                 "name": "\u308c\u3068\u308d\u307f\u3089\u3044",
#                 "screen_name": "Retromirai",
#                 "location": "",
#                 "description": "\u3086\u308b\u3044\u7d75\u3092\u63cf\u3044\u305f\u308a\u3001\u97f3\u697d\u3092\u4f5c\u3063\u305f\u308a\u3057\u307e\u3059\u3002 \u3086\u3081\u306b\u3063\u304d(\u6d3e\u751f)\u3068\u8eca\u3068\u97f3\u697d(YMO\u3001kraftwerk\u3001\u59eb\u795e\u3001Raujika)\u3068\u30ab\u30ec\u30fc\u304c\u597d\u304d\u3002\u3042\uff01\u3042\u3068\u304a\u7b11\u3044\u3081\u3063\u3061\u3083\u597d\u304d\u3067\u3059\u3002",
#                 "url": "https://t.co/NCJPW1mXZT",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/NCJPW1mXZT",
#                                 "expanded_url": "https://soundcloud.com/retromirai",
#                                 "display_url": "soundcloud.com/retromirai",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 1072,
#                 "friends_count": 762,
#                 "listed_count": 24,
#                 "created_at": "Thu Feb 28 09:17:45 +0000 2019",
#                 "favourites_count": 9289,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 4065,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1251850696741142528/rlNgzmWB_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1251850696741142528/rlNgzmWB_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1101048800045543425/1625179949",
#                 "profile_link_color": "F8E9CC",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 9,
#             "favorite_count": 36,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "und"
#         },
#         "is_quote_status": false,
#         "retweet_count": 9,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "und"
#     }
# ]

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 6. Extracting text, screen names, and hashtags from tweets

# %%
import time


status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "#AE86 #\u30c8\u30ec\u30ce #\u982d\u6587\u5b57D #\u90e8\u54c1\u53d6\u308a #COROLLA #\u30cf\u30c1\u30de\u30eb\u30d2\u30fc\u30ed\u30fc\n#\u30cf\u30c1\u30ed\u30af\u58f2\u308a\u307e\u3059 #TOYOTA #\u30ec\u30d3\u30f3 #TORENO #LEVIN\n\u7686\u3055\u3093\u6ca2\u5c71\u306e\u8cfc\u5165\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\u3000\u3055\u3089\u306b\u8ffd\u52a0\u3057\u307e\u3059\uff01\n\u8efd\u81ea\u52d5\u8eca\u30d1\u2026 https://t.co/sU1Jv393Yo",
#  "RT @auto_moto_pl: \u27a1\ufe0f\ud83c\uddef\ud83c\uddf5 #Toyota dostarczy\u0142a ogniwa paliwowe do prototypowego poci\u0105gu elektryczno-wodorowego\n \n\ud83d\udd38Toyota uczestniczy w europejs\u2026",
#  "2016 #Toyota 4Runner Limited https://t.co/SF7cIV2LIW https://t.co/dUWYUy5aN2",
#  "Three types of #inefficiencies that may be impacting your #businessprocesses. The #Toyota 3M model can help you und\u2026 https://t.co/QpXJ29oZQY",
#  "RT @Toyota_Kenya: #LC300 Coming through deep down in the woods.\n#ToyotaKenyaExperience #Toyota #LandCruiser https://t.co/hnARjFQeXf"
# ]
# [
#  "auto_moto_pl",
#  "Toyota_Kenya",
#  "eBay",
#  "Fireprofcargo7",
#  "WeArePlayground"
# ]
# [
#  "AE86",
#  "\u30c8\u30ec\u30ce",
#  "\u982d\u6587\u5b57D",
#  "\u90e8\u54c1\u53d6\u308a",
#  "COROLLA"
# ]
# [
#  "#AE86",
#  "#\u30c8\u30ec\u30ce",
#  "#\u982d\u6587\u5b57D",
#  "#\u90e8\u54c1\u53d6\u308a",
#  "#COROLLA"
# ]

# %% [markdown]
# # Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [('#Toyota', 80), ('RT', 57), ('Toyota', 51), ('the', 31), ('#toyota', 31), ('to', 24), ('el', 24), ('#TOYOTA', 22), ('.', 21), ('in', 16)]
# [('drivingdotca', 10), ('Retromirai', 6), ('TOYOTA_PR', 5), ('car_watch', 5), ('Toyota', 3), ('auto_moto_pl', 2), ('eBay', 2), ('motorytu', 2), ('iMotorZOOM', 2), ('Macers_Media', 2)]
# [('Toyota', 87), ('toyota', 33), ('TOYOTA', 25), ('トヨタ', 15), ('autonews', 10), ('tjcruiser', 6), ('illustraion', 6), ('ForzaHorizon5', 4), ('RAV4', 4), ('carretera', 4)]

# %% [markdown]
# # Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +---------+-------+
# | Word    | Count |
# +---------+-------+
# | #Toyota |    80 |
# | RT      |    57 |
# | Toyota  |    51 |
# | the     |    31 |
# | #toyota |    31 |
# | to      |    24 |
# | el      |    24 |
# | #TOYOTA |    22 |
# | .       |    21 |
# | in      |    16 |
# +---------+-------+
# +--------------+-------+
# | Screen Name  | Count |
# +--------------+-------+
# | drivingdotca |    10 |
# | Retromirai   |     6 |
# | TOYOTA_PR    |     5 |
# | car_watch    |     5 |
# | Toyota       |     3 |
# | auto_moto_pl |     2 |
# | eBay         |     2 |
# | motorytu     |     2 |
# | iMotorZOOM   |     2 |
# | Macers_Media |     2 |
# +--------------+-------+
# +---------------+-------+
# | Hashtag       | Count |
# +---------------+-------+
# | Toyota        |    87 |
# | toyota        |    33 |
# | TOYOTA        |    25 |
# | トヨタ        |    15 |
# | autonews      |    10 |
# | tjcruiser     |     6 |
# | illustraion   |     6 |
# | ForzaHorizon5 |     4 |
# | RAV4          |     4 |
# | carretera     |     4 |
# +---------------+-------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.590625
# 0.6236559139784946
# 0.523972602739726
# 14.4

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+-------------+----------------------------------------------------+
# | Count | Screen Name | Text                                               |
# +-------+-------------+----------------------------------------------------+
# | 682   | CVbu_desu   | RT @CVbu_desu: 竹達彩奈（@Ayana_take）にクラウンに声を当ててもらったら、な |
# |       |             | ぜかあのレジェンド（@Diggy_staff)）とラップ対決になった。 |
# |       |             |                                                    |
# |       |             | ▼全編はこちらから                                  |
# |       |             | https://t.co/A0r1CTyrUV                            |
# |       |             |                                                    |
# |       |             | #CV部 #TOYOTA #CRO…                                |
# | 676   | TOYOTA_PR   | RT @TOYOTA_PR: 📢#北京2022 まで＼あと17日！／      |
# |       |             | 5歳でスケートを始めた #フィギュアスケート に出場予定の #宇野昌磨 |
# |       |             | 選手はジュニア時代から頭角を現し、タイトルを総なめ。 |
# |       |             | 史上初の4回転フリップ成功でギネス記録を持つ、日本スケート界のホープ！ |
# |       |             |                                                    |
# |       |             | #TOY…                                              |
# | 676   | TOYOTA_PR   | RT @TOYOTA_PR: 📢#北京2022 まで＼あと17日！／      |
# |       |             | 5歳でスケートを始めた #フィギュアスケート に出場予定の #宇野昌磨 |
# |       |             | 選手はジュニア時代から頭角を現し、タイトルを総なめ。 |
# |       |             | 史上初の4回転フリップ成功でギネス記録を持つ、日本スケート界のホープ！ |
# |       |             |                                                    |
# |       |             | #TOY…                                              |
# | 350   | AnnisNaeem  | RT @AnnisNaeem: Here it is! I Directed, Produced   |
# |       |             | this video through my studio Plumehead with a      |
# |       |             | bunch of INSANELY talented peeps for the all…      |
# | 141   | Toyota      | RT @Toyota: The all-new GR86 is built with a more  |
# |       |             | refined, athletic look that lives up to its        |
# |       |             | performance. #toyota https://t.co/NMDRnLaDlh       |
# +-------+-------------+----------------------------------------------------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# #  Example 11. Plotting frequencies of words

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  


word_counts = sorted(Counter(words).values(), reverse=True)



plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5, 0, 'Word Rank')

# %% [markdown]
# # Example 12. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print(counts)
# Out:
# [4, 2, 3, 7, 2, 2, 6, 1, 3, 9, 2, 137, 2, 1, 2, 2, 3, 22, 22, 1, 2, 1, 350, 1, 5, 5, 141, 676, 2, 22, 1, 65, 1, 3, 2, 11, 5, 1, 22, 9, 682, 7, 676, 19, 3, 2, 22, 9, 6, 13, 11, 9, 9, 2, 1, 8, 9]
